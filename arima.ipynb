# %% [markdown]
# # filling the missing data

# %%
#missing data filled
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
get_ipython().magic('matplotlib inline')

df = pd.read_csv('desu.csv')
df_null = df['DEXUSUK'].isnull()
df_null[df_null==True].count() #'0' means No Null values
df[df.DEXUSUK=='.']
df[df.DEXUSUK=='.'].count()
df_missing = df.DEXUSUK[df.DEXUSUK=='.']
missing_indexes = np.array(df_missing.index).astype(int)

for i in missing_indexes:
    if df.DEXUSUK[i+5]=='.':
        df.DEXUSUK[i] = (float(df.DEXUSUK[i-1]) + float(df.DEXUSUK[i+6]))/2
    elif df.DEXUSUK[i+4]=='.':
        df.DEXUSUK[i] = (float(df.DEXUSUK[i-1]) + float(df.DEXUSUK[i+5]))/2
    elif df.DEXUSUK[i+3]=='.':
        df.DEXUSUK[i] = (float(df.DEXUSUK[i-1]) + float(df.DEXUSUK[i+4]))/2
    elif df.DEXUSUK[i+2]=='.':
        df.DEXUSUK[i] = (float(df.DEXUSUK[i-1]) + float(df.DEXUSUK[i+3]))/2
    elif df.DEXUSUK[i+1]=='.':
        df.DEXUSUK[i] = (float(df.DEXUSUK[i-1]) + float(df.DEXUSUK[i+2]))/2
    else :
        df.DEXUSUK[i] = (float(df.DEXUSUK[i-1]) + float(df.DEXUSUK[i+1]))/2
# check for missing values

df.DATE = pd.to_datetime(df.DATE)
df.DEXUSUK = pd.to_numeric(df.DEXUSUK)
df.set_index('DATE',inplace=True)

df.plot(y='DEXUSUK',figsize=(15,5))

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['1971-01-04', '1971-01-05', '1971-01-06', '1971-01-07',
#                '1971-01-08', '1971-01-11', '1971-01-12', '1971-01-13',
#                '1971-01-14', '1971-01-15',
#                ...
#                '2018-04-30', '2018-05-01', '2018-05-02', '2018-05-03',
#                '2018-05-04', '2018-05-07', '2018-05-08', '2018-05-09',
#                '2018-05-10', '2018-05-11'],
#               dtype='datetime64[ns]', name='DATE', length=12355, freq=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12355 entries, 1971-01-04 to 2018-05-11
# Data columns (total 1 columns):
# DEXUSUK    12355 non-null float64
# dtypes: float64(1)
# memory usage: 193.0 KB

# %%
df.describe()
# Out:
#             DEXUSUK
# count  12355.000000
# mean       1.738982
# std        0.314593
# min        1.052000
# 25%        1.534800
# 50%        1.642500
# 75%        1.880775
# max        2.644000

# %% [markdown]
# # filling the missing values

# %%
#missing dates filled
idx = pd.date_range('1971-01-01', '2018-05-10')
ts=df['DEXUSUK']
s = pd.Series(ts)
s.index = pd.DatetimeIndex(s.index)

s = s.reindex(idx, fill_value="NaN")
s = s.astype(float)

s = s.interpolate(method='linear', axis=0).ffill().bfill()
print(s)
# Out:
# 1971-01-01    2.393800
# 1971-01-02    2.393800
# 1971-01-03    2.393800
# 1971-01-04    2.393800
# 1971-01-05    2.394900
# 1971-01-06    2.396700
# 1971-01-07    2.396300
# 1971-01-08    2.397200
# 1971-01-09    2.397867
# 1971-01-10    2.398533
# 1971-01-11    2.399200
# 1971-01-12    2.400100
# 1971-01-13    2.402100
# 1971-01-14    2.407100
# 1971-01-15    2.405700
# 1971-01-16    2.405533
# 1971-01-17    2.405367
# 1971-01-18    2.405200
# 1971-01-19    2.408100
# 1971-01-20    2.408000
# 1971-01-21    2.409200
# 1971-01-22    2.410300
# 1971-01-23    2.411767
# 1971-01-24    2.413233
# 1971-01-25    2.414700
# 1971-01-26    2.416000
# 1971-01-27    2.416100
# 1971-01-28    2.416900
# 1971-01-29    2.417400
# 1971-01-30    2.417733
#                 ...
# 2018-04-11    1.419400
# 2018-04-12    1.424400
# 2018-04-13    1.425500
# 2018-04-14    1.428067
# 2018-04-15    1.430633
# 2018-04-16    1.433200
# 2018-04-17    1.430100
# 2018-04-18    1.422700
# 2018-04-19    1.419300
# 2018-04-20    1.403300
# 2018-04-21    1.400633
# 2018-04-22    1.397967
# 2018-04-23    1.395300
# 2018-04-24    1.397500
# 2018-04-25    1.394100
# 2018-04-26    1.392700
# 2018-04-27    1.378500
# 2018-04-28    1.377367
# 2018-04-29    1.376233
# 2018-04-30    1.375100
# 2018-05-01    1.361100
# 2018-05-02    1.361000
# 2018-05-03    1.356900
# 2018-05-04    1.353500
# 2018-05-05    1.354567
# 2018-05-06    1.355633
# 2018-05-07    1.356700
# 2018-05-08    1.352100
# 2018-05-09    1.356700
# 2018-05-10    1.348700
# Freq: D, Name: DEXUSUK, Length: 17297, dtype: float64

# %%
s.describe()
# Out:
# count    17297.000000
# mean         1.739011
# std          0.314588
# min          1.052000
# 25%          1.534700
# 50%          1.642300
# 75%          1.880500
# max          2.644000
# Name: DEXUSUK, dtype: float64

# %%
df1=s['1971-01']

# %%
df1.describe()
# Out:
# count    31.000000
# mean      2.405306
# std       0.008396
# min       2.393800
# 25%       2.397533
# 50%       2.405533
# 75%       2.412500
# max       2.418067
# Name: DEXUSUK, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.plot(s)
plt.tick_params(axis='both', which='major', labelsize=30)

# %% [markdown]
# # Converting into month-wise data

# %%
mnth=s.groupby( pd.Grouper( freq='M')).mean()
plt.figure(figsize=(50,20))
plt.xlabel('date',size=20)
plt.ylabel('price',size=20)
plt.plot(mnth)

# %%
monthn=mnth

# %%
#PIVOT TABLE
plt.figure(figsize=(30,10))
plt.xlabel('date',size=20)
plt.ylabel('price',size=20)
mnth=mnth.to_frame()

mnth['month'] = mnth.index.month
mnth['Year'] = mnth.index.year
piv = pd.pivot_table(mnth, index=['month'],columns=['Year'], values=['DEXUSUK'])

piv.plot()
plt.gca().legend_.remove()


piv
# Out:
#         DEXUSUK                                                              \
# Year       1971      1972      1973      1974      1975      1976      1977
# month
# 1      2.405306  2.570852  2.355758  2.225565  2.361471  2.028460  1.711874
# 2      2.417670  2.603583  2.424311  2.274170  2.393898  2.025891  1.709714
# 3      2.418794  2.617787  2.471742  2.339452  2.417558  1.939694  1.717390
# 4      2.417697  2.610347  2.483657  2.389333  2.369400  1.846057  1.718980
# 5      2.418616  2.612390  2.530929  2.413645  2.320169  1.804787  1.718345
# 6      2.418887  2.572123  2.576414  2.389700  2.278792  1.763817  1.719120
# 7      2.418500  2.443723  2.539668  2.389748  2.184587  1.784994  1.722623
# 8      2.434111  2.450148  2.475855  2.346444  2.114274  1.782635  1.739629
# 9      2.468760  2.441392  2.421043  2.316741  2.084183  1.730987  1.742900
aN       NaN       NaN       NaN       NaN

# %% [markdown]
# # Cross correlation

# %%
corr1 = piv1.corr(method='pearson', min_periods=1)
print(corr1)
# Out:
#                 DEXUSUK                                                    \
# month                1         2         3         4         5         6
#         month
# DEXUSUK 1      1.000000  0.994761  0.984770  0.972154  0.955291  0.930270
#         2      0.994761  1.000000  0.991960  0.978722  0.965064  0.945389
#         3      0.984770  0.991960  1.000000  0.994131  0.980760  0.962061
#         4      0.972154  0.978722  0.994131  1.000000  0.991963  0.977398
#         5      0.955291  0.965064  0.980760  0.991963  1.000000  0.992197
#         6      0.930270  0.945389  0.962061  0.977398  0.992197  1.000000
#         7      0.901466  0.918487  0.931433  0.950505  0.967574  0.986097
#         8      0.891066  0.909473  0.917497  0.936475  0.956393  0.976366
#         9      0.885385  0.903432  0.910347  0.929474  0.950831  0.968611
#         10     0.860165  0.878269  0.885471  0.906004  0.926187  0.943861
#         11     0.832371  0.851512  0.858411  0.879326  0.899052  0.913376
#         12     0.821760  0.839864  0.845749  0.864974  0.882571  0.894743
#
#
# month                7         8         9         10        11        12
#         month
# DEXUSUK 1      0.901466  0.891066  0.885385  0.860165  0.832371  0.821760
#         2      0.918487  0.909473  0.903432  0.878269  0.851512  0.839864
#         3      0.931433  0.917497  0.910347  0.885471  0.858411  0.845749
#         4      0.950505  0.936475  0.929474  0.906004  0.879326  0.864974
#         5      0.967574  0.956393  0.950831  0.926187  0.899052  0.882571
#         6      0.986097  0.976366  0.968611  0.943861  0.913376  0.894743
#         7      1.000000  0.993780  0.983853  0.960714  0.926948  0.910342
#         8      0.993780  1.000000  0.993713  0.972734  0.940611  0.926696
#         9      0.983853  0.993713  1.000000  0.987646  0.962004  0.951161
#         10     0.960714  0.972734  0.987646  1.000000  0.987937  0.976619
#         11     0.926948  0.940611  0.962004  0.987937  1.000000  0.993186
#         12     0.910342  0.926696  0.951161  0.976619  0.993186  1.000000

# %% [markdown]
# # Heatmap

# %%
#heatmap for correlation between different months
import seaborn as sns
# %matplotlib inline
import calendar

# plot the heatmap
ax=sns.heatmap(corr1, 
        xticklabels="",
        yticklabels="")
ax.set_ylabel('')    
ax.set_xlabel('')
ax.plot()
plt.xticks(np.arange(12), calendar.month_name[1:13], rotation=90)
plt.yticks(np.arange(12), calendar.month_name[1:13], rotation=0)
plt.tick_params(axis='both', which='major', labelsize=14)

# %%
mnth1=s.groupby( pd.Grouper( freq='M')).mean()
plt.figure(figsize=(30,10))
plt.xlabel('Date',size=30)
plt.ylabel('Price',size=30)
plt.plot(mnth1)
plt.tick_params(axis='both', which='major', labelsize=30)

# %%
x=mnth1.values

# %% [markdown]
# ### Mann-Kendall Test

# %%
 from scipy.stats import norm

n = len(x)
s2 = 0
for k in range(n-1):
    for j in range(k+1, n):
        s2 += np.sign(x[j] - x[k])

    # calculate the unique data
unique_x = np.unique(x)
g = len(unique_x)

    # calculate the var(s)
if n == g:  # there is no tie
    var_s = (n*(n-1)*(2*n+5))/18
else:  # there are some ties in data
    tp = np.zeros(unique_x.shape)
    for i in range(len(unique_x)):
        tp[i]= sum(x== unique_x[i])
    var_s = (n*(n-1)*(2*n+5) - np.sum(tp*(tp-1)*(2*tp+5)))/18

if s2 > 0:
    z = (s2 - 1)/np.sqrt(var_s)
elif s2 < 0:
    z = (s2 + 1)/np.sqrt(var_s)
else: # s == 0:
    z = 0

    # calculate the p_value
p = 2*(1-norm.cdf(abs(z)))  # two tail test
h = abs(z) > norm.ppf(1-0.05/2)

if (z < 0) and h:
    trend = 'decreasing'
elif (z > 0) and h:
     trend = 'increasing'
else:
    trend = 'no trend'

print(trend)
print(h)
print(p)
print(z)
# Out:
# decreasing
# True
# 0.0
# -12.877804177172939

# %% [markdown]
# # Seasonal Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(mnth1)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
plt.figure(figsize=(26,10))
plt.subplot(411)
plt.plot(mnth1, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
plt.figure(figsize=(30,6))
plt.plot(residual,label='Residual',color='r')
plt.legend(loc='best', prop={'size':20})
plt.tick_params(axis='both', which='major', labelsize=30)

# %%
plt.plot(residual)

# %% [markdown]
# residual

# %%
import warnings
import itertools

import statsmodels.api as sm

# %%
plt.style.use('fivethirtyeight')

# %%
y_train = mnth1[:'2000']
y_test = mnth1['2001':]

# %%
residual
# Out:
# 1971-07-31   -0.037482
# 1971-08-31   -0.033226
# 1971-09-30   -0.010081
# 1971-10-31   -0.004367
# 1971-11-30   -0.016702
# 1971-12-31   -0.002666
# 1972-01-31    0.033172
# 1972-02-29    0.066779
# 1972-03-31    0.088126
# 1972-04-30    0.077056
# 1972-05-31    0.084105
# 1972-06-30    0.061408
# 1972-07-31   -0.053557
# 1972-08-31   -0.027411
# 1972-09-30   -0.018078
# 1972-10-31   -0.051870
# 1972-11-30   -0.087092
# 1972-12-31   -0.094506
# 1973-01-31   -0.089160
# 1973-02-28   -0.023081
# 1973-03-31    0.030797
# 1973-04-30    0.033442
# 1973-05-31    0.072893
# 1973-06-30    0.122062
# 1973-07-31    0.088806
# 1973-08-31    0.039962
# 1973-09-30    0.001453
# 1973-10-31    0.019874
# 1973-11-30   -0.011718
# 1973-12-31   -0.074502
#                 ...
# 2015-06-30    0.025581
# 2015-07-31    0.026182
# 2015-08-31    0.037724
# 2015-09-30    0.026166
# 2015-10-31    0.033025
# 2015-11-30    0.023371
# 2015-12-31    0.008460
# 2016-01-31   -0.034341
# 2016-02-29   -0.023374
# 2016-03-31    0.001184
# 2016-04-30    0.019175
# 2016-05-31    0.058262
# 2016-06-30    0.051393
# 2016-07-31   -0.037701
# 2016-08-31   -0.023780
# 2016-09-30    0.002910
# 2016-10-31   -0.061592
# 2016-11-30   -0.038718
# 2016-12-31   -0.027378
# 2017-01-31   -0.033300
# 2017-02-28   -0.017019
# 2017-03-31   -0.024776
# 2017-04-30   -0.008337
# 2017-05-31    0.008424
# 2017-06-30   -0.006859
# 2017-07-31    0.000193
# 2017-08-31   -0.013792
# 2017-09-30    0.014582
# 2017-10-31   -0.008729
# 2017-11-30   -0.016281
# Freq: M, Name: DEXUSUK, Length: 557, dtype: float64

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf

# %%
lag_acf = acf(residual, nlags=50)
lag_pacf = pacf(residual, nlags=50, method='ols')

# %%
#Plot ACF: 
plt.figure(figsize=(30,6))

plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(residual)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(residual)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5,1,'Autocorrelation Function')

# %%
#Plot PACF:
plt.figure(figsize=(30,6))

plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(residual)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(residual)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
train =residual[:500]
test = residual[500:]
model = ARIMA(train, order=(2,0,2))

# %%
model_fit = model.fit(disp = 1)
print(model_fit.summary())
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\Users\Dell\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# C:\Users\Dell\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                DEXUSUK   No. Observations:                  500
# Model:                     ARMA(2, 2)   Log Likelihood                1045.695
# Method:                       css-mle   S.D. of innovations              0.030
# Date:                Sat, 21 Jul 2018   AIC                          -2079.390
# Time:                        20:55:04   BIC                          -2054.102
# Sample:                    07-31-1971   HQIC                         -2069.467
#                          - 02-28-2013
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -6.428e-05   9.18e-05     -0.700      0.484      -0.000       0.000
# ar.L1.DEXUSUK     1.5144      0.040     37.530      0.000       1.435       1.594
# ar.L2.DEXUSUK    -0.6518      0.040    -16.314      0.000      -0.730      -0.573
# ma.L1.DEXUSUK    -0.6122      0.049    -12.601      0.000      -0.707      -0.517
# ma.L2.DEXUSUK    -0.3876      0.048     -8.027      0.000      -0.482      -0.293
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1618           -0.4296j            1.2387           -0.0564
# AR.2            1.1618           +0.4296j            1.2387            0.0564
# MA.1            1.0002           +0.0000j            1.0002            0.0000
# MA.2           -2.5795           +0.0000j            2.5795            0.5000
# -----------------------------------------------------------------------------

# %%
predictions = model_fit.predict(start=500,end=580)
print(predictions)

plt.plot(predictions)
# Out:
# 2013-03-31   -0.029115
# 2013-04-30   -0.028386
# 2013-05-31   -0.024022
# 2013-06-30   -0.017887
# 2013-07-31   -0.011441
# 2013-08-31   -0.005677
# 2013-09-30   -0.001150
# 2013-10-31    0.001950
# 2013-11-30    0.003694
# 2013-12-31    0.004314
# 2014-01-31    0.004117
# 2014-02-28    0.003414
# 2014-03-31    0.002479
# 2014-04-30    0.001520
# 2014-05-31    0.000677
# 2014-06-30    0.000026
# 2014-07-31   -0.000411
# 2014-08-31   -0.000648
# 2014-09-30   -0.000722
# 2014-10-31   -0.000680
# 2014-11-30   -0.000568
# 2014-12-31   -0.000426
# 2015-01-31   -0.000284
# 2015-02-28   -0.000161
# 2015-03-31   -0.000068
# 2015-04-30   -0.000006
# 2015-05-31    0.000026
# 2015-06-30    0.000034
# 2015-07-31    0.000026
# 2015-08-31    0.000009
#                 ...
# 2017-06-30   -0.000064
# 2017-07-31   -0.000065
# 2017-08-31   -0.000065
# 2017-09-30   -0.000065
# 2017-10-31   -0.000065
# 2017-11-30   -0.000064
# 2017-12-31   -0.000064
# 2018-01-31   -0.000064
# 2018-02-28   -0.000064
# 2018-03-31   -0.000064
# 2018-04-30   -0.000064
# 2018-05-31   -0.000064
# 2018-06-30   -0.000064
# 2018-07-31   -0.000064
# 2018-08-31   -0.000064
# 2018-09-30   -0.000064
# 2018-10-31   -0.000064
# 2018-11-30   -0.000064
# 2018-12-31   -0.000064
# 2019-01-31   -0.000064
# 2019-02-28   -0.000064
# 2019-03-31   -0.000064
# 2019-04-30   -0.000064
# 2019-05-31   -0.000064
# 2019-06-30   -0.000064
# 2019-07-31   -0.000064
# 2019-08-31   -0.000064
# 2019-09-30   -0.000064
# 2019-10-31   -0.000064
# 2019-11-30   -0.000064
# Freq: M, Length: 81, dtype: float64
# C:\Users\Dell\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %%
y_forecasted =predictions
y_truth = residual[499:]
from math import sqrt
# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
rmse=np.sqrt(mse)
print('The Mean Squared Error of our forecasts is {}'.format(round(rmse, 4)))
# Out:
# The Mean Squared Error of our forecasts is 0.0276
